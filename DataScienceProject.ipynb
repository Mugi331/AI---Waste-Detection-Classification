# %% [markdown]
# <a href="https://colab.research.google.com/github/Mugi331/AI---Waste-Detection-Classification/blob/main/DataScienceProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# define project path
from pathlib import Path

PROJECT_ROOT = Path(
    "/content/drive/MyDrive/Data Science Shared Workspace"
)

DATA_RAW_DIR = PROJECT_ROOT / "01_data" / "raw"
DATA_INTERIM_DIR = PROJECT_ROOT / "01_data" / "interim"
DATA_PROCESSED_DIR = PROJECT_ROOT / "01_data" / "processed"

NOTEBOOK_DIR = PROJECT_ROOT / "02_notebooks" / "development"

FIGURE_DIR = PROJECT_ROOT / "03_outputs" / "figures"
TABLE_DIR = PROJECT_ROOT / "03_outputs" / "tables"
PREDICTION_DIR = PROJECT_ROOT / "03_outputs" / "predictions"

MODEL_EXPERIMENT_DIR = PROJECT_ROOT / "04_models" / "experiments"
MODEL_FINAL_DIR = PROJECT_ROOT / "04_models" / "final"

print(f"Project root: {PROJECT_ROOT}")
print(f"Exists: {PROJECT_ROOT.exists()}")
# Out:
# Project root: /content/drive/MyDrive/Data Science Shared Workspace
# Exists: True

# %%
# verify if all folders exist
project_directories = {
    "Raw data": DATA_RAW_DIR,
    "Interim data": DATA_INTERIM_DIR,
    "Processed data": DATA_PROCESSED_DIR,
    "Figures": FIGURE_DIR,
    "Tables": TABLE_DIR,
    "Predictions": PREDICTION_DIR,
    "Experimental models": MODEL_EXPERIMENT_DIR,
    "Final model": MODEL_FINAL_DIR,
}

for name, path in project_directories.items():
    status = "FOUND" if path.exists() else "MISSING"
    print(f"{name:<22} {status:<8} {path}")
# Out:
# Raw data               FOUND    /content/drive/MyDrive/Data Science Shared Workspace/01_data/raw
# Interim data           FOUND    /content/drive/MyDrive/Data Science Shared Workspace/01_data/interim
# Processed data         FOUND    /content/drive/MyDrive/Data Science Shared Workspace/01_data/processed
# Figures                FOUND    /content/drive/MyDrive/Data Science Shared Workspace/03_outputs/figures
# Tables                 FOUND    /content/drive/MyDrive/Data Science Shared Workspace/03_outputs/tables
# Predictions            FOUND    /content/drive/MyDrive/Data Science Shared Workspace/03_outputs/predictions
# Experimental models    FOUND    /content/drive/MyDrive/Data Science Shared Workspace/04_models/experiments
# Final model            FOUND    /content/drive/MyDrive/Data Science Shared Workspace/04_models/final

# %%
# test file creation
test_file = PROJECT_ROOT / "workspace_test.txt"

test_file.write_text(
    "Google Colab can write to the shared project folder.",
    encoding="utf-8",
)

print(f"Created: {test_file}")
print(f"File exists: {test_file.exists()}")
# Out:
# Created: /content/drive/MyDrive/Data Science Shared Workspace/workspace_test.txt
# File exists: True

# %%
# Check required libraries
import sys
import importlib.util

required_packages = {
    "pandas": "pandas",
    "numpy": "numpy",
    "matplotlib": "matplotlib",
    "sklearn": "scikit-learn",
    "xgboost": "xgboost",
    "joblib": "joblib",
}

print(f"Python version: {sys.version}\n")

for import_name, package_name in required_packages.items():
    installed = importlib.util.find_spec(import_name) is not None
    status = "INSTALLED" if installed else "NOT INSTALLED"
    print(f"{package_name:<15} {status}")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# pandas          INSTALLED
# numpy           INSTALLED
# matplotlib      INSTALLED
# scikit-learn    INSTALLED
# xgboost         INSTALLED
# joblib          INSTALLED
